# %%
pwd
# Out:
# '/content/drive/My Drive/Project_tasks/Mobilenet/models/research/object_detection'

# %%
tensorboard --logdir=Training\

# %%
pip install tensorboardcolab

# %%
# !kill 4441
# Out:
# /bin/bash: line 0: kill: (4441) - No such process

# %%
! tensorboard --logdir='Training'

# %%
# %tensorboard --logdir logs

# %%
# %load_ext tensorboard
# %tensorboard --logdir="/content/drive/My Drive/Project_tasks/Mobilenet/models/research/object_detection/Training/"

# %%
# %reload_ext tensorboard

# %%
# !kill 2661

# %%
! powershell "echo 'checking for existing tensorboard processes'"
! powershell "ps | Where-Object {$_.ProcessName -eq 'tensorboard'}"

! powershell "ps | Where-Object {$_.ProcessName -eq 'tensorboard'}| %{kill $_}"

! powershell "echo 'cleaning tensorboard temp dir'"
! powershell "rm $env:TEMP\.tensorboard-info\*"

! powershell "ps | Where-Object {$_.ProcessName -eq 'tensorboard'}"

# %%
# %tensorboard --logdir=/Training  --inspect
# Out:
# ERROR: Failed to launch TensorBoard (exited with 0).
# Contents of stderr:
# 2020-05-19 02:23:31.351683: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Contents of stdout:
# ...
# Processing event files... (this can take a few minutes)
# ...
#
# No event files found within logdir /Training

# %%
cd /content/drive/My Drive/Project_tasks/Mobilenet/models/research/object_detection
# Out:
# /content/drive/My Drive/Project_tasks/Mobilenet/models/research/object_detection
